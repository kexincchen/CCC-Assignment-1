# %%
import json
import pandas as pd
from datetime import datetime

# Load the JSON data from file
with open('data/twitter-1mb.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

# Convert the 'rows' list to a DataFrame
tweets_data = data['rows']
df = pd.DataFrame(data)

# %%
data
# Out:
# {'total_rows': 185875709,
#  'offset': 0,
#  'rows': [{'id': '1406813874750300166',
#    'key': [2021,
#     6,
#     21,
#     '1405853521107324933',
#     '1055330142313046016',
#     '1406813874750300166'],
#    'value': {'text': 'Such a cute pupper 😍'},
#    'doc': {'_id': '1406813874750300166',
#     '_rev': '1-1a7924e962def1c92ecd08ee1537ea1b',
#     'data': {'author_id': '1055330142313046016',
#      'conversation_id': '1405853521107324933',
#      'created_at': '2021-06-21T03:18:59.000Z',
#      'entities': {'mentions': [{'start': 0,
#         'end': 13,
#         'username': 'pup_chazable'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@pup_chazable Such a cute pupper 😍',
#      'sentiment': 0.7142857142857143},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406814402272137216',
#    'key': [2021,
#     6,
#     21,
#     '1405853521107324933',
#     '1404371196267819012',
#     '1406814402272137216'],
#    'value': {'text': 'Nawww thanks! 🥰 *Nuzzles* right back at ya pup! 😝'},
#    'doc': {'_id': '1406814402272137216',
#     '_rev': '1-d6ce7e1e33721a9f3aed148b2cc1a64c',
#     'data': {'author_id': '1404371196267819012',
#      'conversation_id': '1405853521107324933',
#      'created_at': '2021-06-21T03:21:05.000Z',
#      'entities': {'mentions': [{'start': 0,
#         'end': 10,
#         'username': 'PupLucky_'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@PupLucky_ Nawww thanks! 🥰 *Nuzzles* right back at ya pup! 😝',
#      'sentiment': 0.36363636363636365},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406920780328312832',
#    'key': [2021,
#     6,
#     21,
#     '1405853729555890177',
#     '831958692786417669',
#     '1406920780328312832'],
#    'value': {'text': 'Just wondered if the peregrines been named yet? What was the result of the competition?'},
#    'doc': {'_id': '1406920780328312832',
#     '_rev': '1-b5f329c5063489fa0863165e1660f367',
#     'data': {'author_id': '831958692786417669',
#      'conversation_id': '1405853729555890177',
#      'created_at': '2021-06-21T10:23:48.000Z',
#      'entities': {'mentions': [{'start': 0, 'end': 5, 'username': 'WKWT'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@WKWT Just wondered if the peregrines been named yet? What was the result of the competition?',
#      'sentiment': 0},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406929052724654084',
#    'key': [2021,
#     6,
#     21,
#     '1405853729555890177',
#     '831958692786417669',
#     '1406929052724654084'],
#    'value': {'text': 'Thanks. Sorry missed that. Great result though.'},
#    'doc': {'_id': '1406929052724654084',
#     '_rev': '1-87635ddc02305a887c0d64952ff47929',
#     'data': {'author_id': '831958692786417669',
#      'conversation_id': '1405853729555890177',
#      'created_at': '2021-06-21T10:56:40.000Z',
#      'entities': {'mentions': [{'start': 0, 'end': 5, 'username': 'WKWT'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@WKWT Thanks. Sorry missed that. Great result though.',
#      'sentiment': 0.25},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406932228165099530',
#    'key': [2021,
#     6,
#     21,
#     '1405853924251226112',
#     '914601022051336192',
#     '1406932228165099530'],
#    'value': {'text': 'Can you point to some of information about this type of illusion?'},
#    'doc': {'_id': '1406932228165099530',
#     '_rev': '1-eb8055d1705034e0b1ee1d93c4cac920',
#     'data': {'author_id': '914601022051336192',
#      'conversation_id': '1405853924251226112',
#      'created_at': '2021-06-21T11:09:17.000Z',
#      'entities': {'mentions': [{'start': 0,
#         'end': 16,
#         'username': 'AkiyoshiKitaoka'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@AkiyoshiKitaoka Can you point to some of information about this type of illusion?',
#      'sentiment': 0},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1407120393576452098',
#    'key': [2021,
#     6,
#     21,
#     '1405854650713133058',
#     '834524111883771904',
#     '1407120393576452098'],
#    'value': {'text': 'It\'s bizarre, who says 3 days is enough to properly treat UTI? "The shortest dose possible" recommendation is creeping into other areas of antibiotic treatment for infections. Antibiotic stewardship needs to consider the dangers of recommending sub-lethal courses of antibiotic.'},
#    'doc': {'_id': '1407120393576452098',
#     '_rev': '1-628ca4a5474745a0fd47e86f8551735e',
#     'data': {'author_id': '834524111883771904',
#      'conversation_id': '1405854650713133058',
#      'created_at': '2021-06-21T23:36:59.000Z',
#      'entities': {'mentions': [{'start': 0,
#         'end': 10,
#         'username': 'aviva1on1'},
#        {'start': 11, 'end': 27, 'username': 'ConfusedBladder'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@aviva1on1 @ConfusedBladder It\'s bizarre, who says 3 days is enough to properly treat UTI?  "The shortest dose possible" recommendation is creeping into other areas of antibiotic treatment for infections. Antibiotic stewardship needs to consider the dangers of recommending sub-lethal courses of antibiotic.',
#      'sentiment': -0.09523809523809523},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406827914046279682',
#    'key': [2021,
#     6,
#     21,
#     '1405855254726459396',
#     '1280488031095406597',
#     '1406827914046279682'],
#    'value': {'text': "Don't you just love black and white photography?"},
#    'doc': {'_id': '1406827914046279682',
#     '_rev': '1-635b217016b27a539c594097b8d2bd51',
#     'data': {'author_id': '1280488031095406597',
#      'conversation_id': '1405855254726459396',
#      'created_at': '2021-06-21T04:14:46.000Z',
#      'entities': {'mentions': [{'start': 0,
#         'end': 16,
#         'username': 'carmedonnafugat'},
#        {'start': 17, 'end': 32, 'username': 'RobertPRowley2'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': "@carmedonnafugat @RobertPRowley2 Don't you just love black and white photography?",
#      'sentiment': 0.3},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406775462332751875',
#    'key': [2021,
#     6,
#     21,
#     '1405855601339502593',
#     '1070268133343027205',
#     '1406775462332751875'],
#    'value': {'text': 'No problem! Hope you had a great weekend!'},
#    'doc': {'_id': '1406775462332751875',
#     '_rev': '1-766b57b6a4169c8ac9515b8c8b6517f3',
#     'data': {'author_id': '1070268133343027205',
#      'conversation_id': '1405855601339502593',
#      'created_at': '2021-06-21T00:46:21.000Z',
#      'entities': {'mentions': [{'start': 0, 'end': 9, 'username': 'ZKuerten'},
#        {'start': 10, 'end': 22, 'username': 'ridishooter'},
#        {'start': 23, 'end': 35, 'username': 'galope_team'},
#        {'start': 36, 'end': 49, 'username': 'MartiansGame'},
#        {'start': 50, 'end': 63, 'username': 'BusGalactica'},
#        {'start': 64, 'end': 78, 'username': 'Chris_N_Tharp'},
#        {'start': 79, 'end': 93, 'username': 'HourADayGamer'},
#        {'start': 94, 'end': 103, 'username': 'PixyDevs'},
#        {'start': 104, 'end': 110, 'username': 'Amlor'},
#        {'start': 111, 'end': 126, 'username': 'conspiracydawg'},
#        {'start': 127, 'end': 143, 'username': 'realsoupmasters'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@ZKuerten @ridishooter @galope_team @MartiansGame @BusGalactica @Chris_N_Tharp @HourADayGamer @PixyDevs @Amlor @conspiracydawg @realsoupmasters No problem! Hope you had a great weekend!',
#      'sentiment': 0.09090909090909091},
#     'matching_rules': [{'id': 1405794688146182100,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406975784338673676',
#    'key': [2021,
#     6,
#     21,
#     '1405855601339502593',
#     '1070268133343027205',
#     '1406975784338673676'],
#    'value': {'text': 'No problem! Hope you had a great weekend as well!'},
#    'doc': {'_id': '1406975784338673676',
#     '_rev': '1-8e51e23092039ef92648ac6477c48c73',
#     'data': {'author_id': '1070268133343027205',
#      'conversation_id': '1405855601339502593',
#      'created_at': '2021-06-21T14:02:21.000Z',
#      'entities': {'mentions': [{'start': 0,
#         'end': 15,
#         'username': 'conspiracydawg'},
#        {'start': 16, 'end': 28, 'username': 'ridishooter'},
#        {'start': 29, 'end': 41, 'username': 'galope_team'},
#        {'start': 42, 'end': 55, 'username': 'MartiansGame'},
#        {'start': 56, 'end': 65, 'username': 'ZKuerten'},
#        {'start': 66, 'end': 79, 'username': 'BusGalactica'},
#        {'start': 80, 'end': 94, 'username': 'Chris_N_Tharp'},
#        {'start': 95, 'end': 109, 'username': 'HourADayGamer'},
#        {'start': 110, 'end': 119, 'username': 'PixyDevs'},
#        {'start': 120, 'end': 126, 'username': 'Amlor'},
#        {'start': 127, 'end': 143, 'username': 'realsoupmasters'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@conspiracydawg @ridishooter @galope_team @MartiansGame @ZKuerten @BusGalactica @Chris_N_Tharp @HourADayGamer @PixyDevs @Amlor @realsoupmasters No problem! Hope you had a great weekend as well!',
#      'sentiment': 0.08333333333333333},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406806053992337412',
#    'key': [2021,
#     6,
#     21,
#     '1405855646080249862',
#     '1059362252271235074',
#     '1406806053992337412'],
#    'value': {'text': 'Your Daddy is the biggest and worst looser ever occupyingthe WH.'},
#    'doc': {'_id': '1406806053992337412',
#     '_rev': '1-69b75ccfc162bc85b963b6d185305fbd',
#     'data': {'author_id': '1059362252271235074',
#      'context_annotations': [{'domain': {'id': '10',
#         'name': 'Person',
#         'description': 'Named people in the world like Nelson Mandela'},
#        'entity': {'id': '884781076484202496',
#         'name': 'Donald Trump Jr.',
#         'description': 'Donald Trump Jr.'}},
#       {'domain': {'id': '88',
#         'name': 'Political Body',
#         'description': 'A section of a government, like The Supreme Court'},
#        'entity': {'id': '871795678447456256',
#         'name': 'The White House',
#         'description': 'Conversation from and about the White House, both as a destination and as political voice'}}],
#      'conversation_id': '1405855646080249862',
#      'created_at': '2021-06-21T02:47:55.000Z',
#      'entities': {'mentions': [{'start': 0,
#         'end': 15,
#         'username': 'DonaldJTrumpJr'},
#        {'start': 16, 'end': 29, 'username': 'TrumpWarRoom'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@DonaldJTrumpJr @TrumpWarRoom Your Daddy is the biggest and worst looser ever occupyingthe WH.',
#      'sentiment': -0.23076923076923078},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406782226214244353',
#    'key': [2021,
#     6,
#     21,
#     '1405855761012563968',
#     '27628183',
#     '1406782226214244353'],
#    'value': {'text': 'Damn I think it’s time for a post pandemic Spice Rack reunion party 🌶 💃🏽'},
#    'doc': {'_id': '1406782226214244353',
#     '_rev': '1-6f5cf0bc9d523682455d141c934f6484',
#     'data': {'author_id': '27628183',
#      'context_annotations': [{'domain': {'id': '123',
#         'name': 'Ongoing News Story',
#         'description': "Ongoing News Stories like 'Brexit'"},
#        'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}],
#      'conversation_id': '1405855761012563968',
#      'created_at': '2021-06-21T01:13:14.000Z',
#      'entities': {'mentions': [{'start': 0,
#         'end': 13,
#         'username': 'dhruvabalram'}]},
#      'geo': {'place_id': '0073b76548e5984f'},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@dhruvabalram Damn I think it’s time for a post pandemic Spice Rack reunion party \n🌶 💃🏽',
#      'sentiment': -0.125},
#     'includes': {'places': [{'full_name': 'Sydney, New South Wales',
#        'geo': {'type': 'Feature',
#         'bbox': [150.520928608, -34.1183470085, 151.343020992, -33.578140996],
#         'properties': {}},
#        'id': '0073b76548e5984f'}]},
#     'matching_rules': [{'id': 1405794688146182100,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406939477369507840',
#    'key': [2021,
#     6,
#     21,
#     '1405855907741945858',
#     '2472276595',
#     '1406939477369507840'],
#    'value': {'text': 'Bu dosya her kimde ise, onlardan alınıp, konusunda uzmanlaşmış, devlet tarafından belirlenecek bir ekibe verilmeli. Herşeyi silbaştan incelemeli ve bilimsel kanıtlar ışığında, özel sorgulama (Reid technique, interrogation) uygulanmalıdır. 21nci yüzyılda olduğumuzuda hatırlatırım!'},
#    'doc': {'_id': '1406939477369507840',
#     '_rev': '1-cea488778b173f76f69a0cc7291f0610',
#     'data': {'author_id': '2472276595',
#      'conversation_id': '1405855907741945858',
#      'created_at': '2021-06-21T11:38:05.000Z',
#      'entities': {'mentions': [{'start': 0,
#         'end': 14,
#         'username': 'BuyuksenOsman'},
#        {'start': 15, 'end': 29, 'username': 'Mugeanliatvde'}]},
#      'geo': {},
#      'lang': 'tr',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@BuyuksenOsman @Mugeanliatvde Bu dosya her kimde ise, onlardan alınıp, konusunda uzmanlaşmış, devlet tarafından belirlenecek bir ekibe verilmeli. Herşeyi silbaştan incelemeli ve bilimsel kanıtlar ışığında, özel sorgulama (Reid technique, interrogation) uygulanmalıdır. 21nci yüzyılda olduğumuzuda hatırlatırım!'},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406933785510170626',
#    'key': [2021,
#     6,
#     21,
#     '1405856070245908484',
#     '2218552680',
#     '1406933785510170626'],
#    'value': {'text': '💯'},
#    'doc': {'_id': '1406933785510170626',
#     '_rev': '1-76fe1f21e64733578b524f646563dff0',
#     'data': {'author_id': '2218552680',
#      'conversation_id': '1405856070245908484',
#      'created_at': '2021-06-21T11:15:28.000Z',
#      'entities': {'mentions': [{'start': 0,
#         'end': 14,
#         'username': 'BeanBagBagus1'},
#        {'start': 15, 'end': 29, 'username': 'PerthWildcats'}]},
#      'geo': {},
#      'lang': 'und',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@BeanBagBagus1 @PerthWildcats 💯'},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406867160580853775',
#    'key': [2021,
#     6,
#     21,
#     '1405856203645755393',
#     '44550243',
#     '1406867160580853775'],
#    'value': {'text': 'No, just working for a living.'},
#    'doc': {'_id': '1406867160580853775',
#     '_rev': '1-50b793a60d897c7b79487991d25ef44e',
#     'data': {'author_id': '44550243',
#      'conversation_id': '1405856203645755393',
#      'created_at': '2021-06-21T06:50:44.000Z',
#      'entities': {'mentions': [{'start': 0,
#         'end': 14,
#         'username': 'redstarcycles'},
#        {'start': 15, 'end': 28, 'username': 'KirstyWebeck'},
#        {'start': 29, 'end': 45, 'username': 'JonesHowdareyou'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@redstarcycles @KirstyWebeck @JonesHowdareyou No, just working for a living.',
#      'sentiment': -0.1111111111111111},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406867352503820289',
#    'key': [2021,
#     6,
#     21,
#     '1405856203645755393',
#     '44550243',
#     '1406867352503820289'],
#    'value': {'text': 'You are making the comment, you give the data'},
#    'doc': {'_id': '1406867352503820289',
#     '_rev': '1-c57c7b1ce5301f38c044c323b7f8e23f',
#     'data': {'author_id': '44550243',
#      'conversation_id': '1405856203645755393',
#      'created_at': '2021-06-21T06:51:29.000Z',
#      'entities': {'mentions': [{'start': 0,
#         'end': 14,
#         'username': 'redstarcycles'},
#        {'start': 15, 'end': 28, 'username': 'KirstyWebeck'},
#        {'start': 29, 'end': 45, 'username': 'JonesHowdareyou'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@redstarcycles @KirstyWebeck @JonesHowdareyou You are making the comment, you give the data',
#      'sentiment': 0},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406924966746935299',
#    'key': [2021,
#     6,
#     21,
#     '1405856203645755393',
#     '44550243',
#     '1406924966746935299'],
#    'value': {'text': 'I put data up, you haven’t bothered. What evidence do you have that I am anti-vax?'},
#    'doc': {'_id': '1406924966746935299',
#     '_rev': '1-49ca240aab1dd7d8a12196824fc1c8eb',
#     'data': {'author_id': '44550243',
#      'conversation_id': '1405856203645755393',
#      'created_at': '2021-06-21T10:40:26.000Z',
#      'entities': {'mentions': [{'start': 0,
#         'end': 14,
#         'username': 'redstarcycles'},
#        {'start': 15, 'end': 28, 'username': 'KirstyWebeck'},
#        {'start': 29, 'end': 45, 'username': 'JonesHowdareyou'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@redstarcycles @KirstyWebeck @JonesHowdareyou I put data up, you haven’t bothered. What evidence do you have that I am anti-vax?',
#      'sentiment': -0.10526315789473684},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406944732907900934',
#    'key': [2021,
#     6,
#     21,
#     '1405856203645755393',
#     '44550243',
#     '1406944732907900934'],
#    'value': {'text': 'Put up the data, opinions don’t matter, data does. TGA website has the data you are looking for, I read it last night.'},
#    'doc': {'_id': '1406944732907900934',
#     '_rev': '1-1a80a64bc8fe0385f650143720c038f2',
#     'data': {'author_id': '44550243',
#      'conversation_id': '1405856203645755393',
#      'created_at': '2021-06-21T11:58:58.000Z',
#      'entities': {'mentions': [{'start': 0,
#         'end': 14,
#         'username': 'redstarcycles'},
#        {'start': 15, 'end': 28, 'username': 'KirstyWebeck'},
#        {'start': 29, 'end': 45, 'username': 'JonesHowdareyou'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@redstarcycles @KirstyWebeck @JonesHowdareyou Put up the data, opinions don’t matter, data does. TGA website has the data you are looking for, I read it last night.',
#      'sentiment': 0.038461538461538464},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406773845357338625',
#    'key': [2021,
#     6,
#     21,
#     '1405856690717741057',
#     '1397697032295378953',
#     '1406773845357338625'],
#    'value': {'text': "it's not luck and its not as hard as people say. It only takes 10 days to form a habit, people just arent educated about tools they have"},
#    'doc': {'_id': '1406773845357338625',
#     '_rev': '1-2c3453fc4ce69fe52175cce8194cf0a8',
#     'data': {'author_id': '1397697032295378953',
#      'conversation_id': '1405856690717741057',
#      'created_at': '2021-06-21T00:39:55.000Z',
#      'entities': {'mentions': [{'start': 0,
#         'end': 15,
#         'username': 'reality_itself'},
#        {'start': 16, 'end': 26, 'username': 'CordOrder'},
#        {'start': 27, 'end': 43, 'username': 'AClownAndCircus'},
#        {'start': 44, 'end': 57, 'username': 'SeekerRaiden'},
#        {'start': 58, 'end': 67, 'username': 'm0thpiss'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': "@reality_itself @CordOrder @AClownAndCircus @SeekerRaiden @m0thpiss it's not luck and its not as hard as people say.\nIt only takes 10 days to form a habit, people just arent educated about tools they have",
#      'sentiment': -0.11764705882352941},
#     'matching_rules': [{'id': 1405794688146182100,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406945907648516098',
#    'key': [2021,
#     6,
#     21,
#     '1405857678367330314',
#     '65684291',
#     '1406945907648516098'],
#    'value': {'text': 'At the end of the day, that verzus would be a celebration of both catalogues 🙏 C'},
#    'doc': {'_id': '1406945907648516098',
#     '_rev': '1-7087602503bf900fb15d1af07ba7066b',
#     'data': {'author_id': '65684291',
#      'conversation_id': '1405857678367330314',
#      'created_at': '2021-06-21T12:03:38.000Z',
#      'entities': {'mentions': [{'start': 0,
#         'end': 10,
#         'username': 'SimbaTagz'},
#        {'start': 11, 'end': 25, 'username': 'KeepitRealFri'},
#        {'start': 26, 'end': 39, 'username': 'MeetLuminous'},
#        {'start': 40, 'end': 50, 'username': 'TRKmusik_'},
#        {'start': 51, 'end': 61, 'username': 'Kae_Chaps'}],
#       'urls': [{'start': 141,
#         'end': 164,
#         'url': 'https://t.co/6FlPjERW9C',
#         'expanded_url': 'https://twitter.com/SELETINE/status/1406945907648516098/photo/1',
#         'display_url': 'pic.twitter.com/6FlPjERW9C'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@SimbaTagz @KeepitRealFri @MeetLuminous @TRKmusik_ @Kae_Chaps At the end of the day, that verzus would be a celebration of both catalogues 🙏 https://t.co/6FlPjERW9C',
#      'sentiment': 0.19230769230769232},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406912622276997122',
#    'key': [2021,
#     6,
#     21,
#     '1405858859680477184',
#     '37895916',
#     '1406912622276997122'],
#    'value': {'text': 'Happy belated birthday h ! Hope you had a lovely beautiful one 💛'},
#    'doc': {'_id': '1406912622276997122',
#     '_rev': '1-f0d271d108723edab99dac3cc3f2f502',
#     'data': {'author_id': '37895916',
#      'context_annotations': [{'domain': {'id': '10',
#         'name': 'Person',
#         'description': 'Named people in the world like Nelson Mandela'},
#        'entity': {'id': '807326243070701568',
#         'name': 'Lorde',
#         'description': 'Lorde'}},
#       {'domain': {'id': '54',
#         'name': 'Musician',
#         'description': 'A musician in the world, like Adele or Bob Dylan'},
#        'entity': {'id': '807326243070701568',
#         'name': 'Lorde',
#         'description': 'Lorde'}},
#       {'domain': {'id': '55',
#         'name': 'Music Genre',
#         'description': 'A category for a musical style, like Pop, Rock, or Rap'},
#        'entity': {'id': '810938279801470977',
#         'name': 'Pop',
#         'description': 'Pop'}}],
#      'conversation_id': '1405858859680477184',
#      'created_at': '2021-06-21T09:51:22.000Z',
#      'entities': {'annotations': [{'start': 41,
#         'end': 45,
#         'probability': 0.9967,
#         'type': 'Person',
#         'normalized_text': 'Sarah'}],
#       'mentions': [{'start': 0, 'end': 10, 'username': 'lordelive'},
#        {'start': 11, 'end': 17, 'username': 'lorde'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@lordelive @lorde Happy belated birthday Sarah ! Hope you had a lovely beautiful one 💛',
#      'sentiment': 1},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406878959178899458',
#    'key': [2021,
#     6,
#     21,
#     '1405859554064158721',
#     '45456175',
#     '1406878959178899458'],
#    'value': {'text': "Sometimes you don't even have to do anything, r unfollows people for you 😩"},
#    'doc': {'_id': '1406878959178899458',
#     '_rev': '1-5a9d2e2e3c18ee54f617cbdc1134897d',
#     'data': {'author_id': '45456175',
#      'context_annotations': [{'domain': {'id': '46',
#         'name': 'Brand Category',
#         'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#        'entity': {'id': '781974596752842752', 'name': 'Services'}},
#       {'domain': {'id': '47',
#         'name': 'Brand',
#         'description': 'Brands and Companies'},
#        'entity': {'id': '10045225402', 'name': 'Twitter'}}],
#      'conversation_id': '1405859554064158721',
#      'created_at': '2021-06-21T07:37:37.000Z',
#      'entities': {'annotations': [{'start': 54,
#         'end': 60,
#         'probability': 0.6701,
#         'type': 'Product',
#         'normalized_text': 'Twitter'}],
#       'mentions': [{'start': 0, 'end': 7, 'username': 'onewpc'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': "@onewpc Sometimes you don't even have to do anything, Twitter unfollows people for you 😩",
#      'sentiment': -0.13333333333333333},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406802872671477762',
#    'key': [2021,
#     6,
#     21,
#     '1405859600935444487',
#     '1087679609146007552',
#     '1406802872671477762'],
#    'value': {'text': 'The same “Brains” that we allow to control us!!'},
#    'doc': {'_id': '1406802872671477762',
#     '_rev': '1-29acbb26878cd7f8d10da267732503b1',
#     'data': {'author_id': '1087679609146007552',
#      'conversation_id': '1405859600935444487',
#      'created_at': '2021-06-21T02:35:16.000Z',
#      'entities': {'mentions': [{'start': 0,
#         'end': 11,
#         'username': 'tonytardio'}]},
#      'geo': {'place_id': '01864a8a64df9dc4'},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@tonytardio The same “Brains” that we allow to control us!!',
#      'sentiment': 0.1},
#     'includes': {'places': [{'full_name': 'Melbourne, Victoria',
#        'geo': {'type': 'Feature',
#         'bbox': [144.593741856, -38.433859306, 145.512528832, -37.5112737225],
#         'properties': {}},
#        'id': '01864a8a64df9dc4'}]},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406881419066966019',
#    'key': [2021,
#     6,
#     21,
#     '1405859978770976768',
#     '2229126852',
#     '1406881419066966019'],
#    'value': {'text': "This is the chthonic level of Australian MSM journalism now. Today the SMH's editor pledged to get to the bottom of this even as she continued to avoid mentioning which govt and which PM ordered it."},
#    'doc': {'_id': '1406881419066966019',
#     '_rev': '1-5416a63ca60942f57fb53058ac33a795',
#     'data': {'author_id': '2229126852',
#      'conversation_id': '1405859978770976768',
#      'created_at': '2021-06-21T07:47:23.000Z',
#      'entities': {'mentions': [{'start': 0,
#         'end': 14,
#         'username': 'thejuicemedia'},
#        {'start': 15, 'end': 21, 'username': 'fangr'}],
#       'urls': [{'start': 221,
#         'end': 244,
#         'url': 'https://t.co/SxpO396O0Y',
#         'expanded_url': 'https://twitter.com/TFalkingham/status/1406881419066966019/photo/1',
#         'display_url': 'pic.twitter.com/SxpO396O0Y'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': "@thejuicemedia @fangr This is the chthonic level of Australian MSM journalism now.\nToday the SMH's editor pledged to get to the bottom of this even as she continued to avoid mentioning which govt and which PM ordered it. https://t.co/SxpO396O0Y",
#      'sentiment': -0.023809523809523808},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406917680146223105',
#    'key': [2021,
#     6,
#     21,
#     '1405860990999093264',
#     '1157534854285688832',
#     '1406917680146223105'],
#    'value': {'text': 'Thank you so much!! Means a lot!'},
#    'doc': {'_id': '1406917680146223105',
#     '_rev': '1-8d6ef15ee6275d5542c9fb2efcbdc036',
#     'data': {'author_id': '1157534854285688832',
#      'context_annotations': [{'domain': {'id': '71',
#         'name': 'Video Game',
#         'description': 'A video game like Overwatch'},
#        'entity': {'id': '1404138543773933568',
#         'name': 'Microsoft Flight Simulator'}}],
#      'conversation_id': '1405860990999093264',
#      'created_at': '2021-06-21T10:11:28.000Z',
#      'entities': {'mentions': [{'start': 0,
#         'end': 10,
#         'username': 'NvidiaANZ'},
#        {'start': 11, 'end': 24, 'username': 'MSFSofficial'},
#        {'start': 25, 'end': 37, 'username': 'AsoboStudio'},
#        {'start': 38, 'end': 46, 'username': 'lillhoo'},
#        {'start': 47, 'end': 60, 'username': 'GamerGram_GG'},
#        {'start': 61, 'end': 74, 'username': 'ThePhotoMode'},
#        {'start': 75, 'end': 91, 'username': '_GameScreenshot'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@NvidiaANZ @MSFSofficial @AsoboStudio @lillhoo @GamerGram_GG @ThePhotoMode @_GameScreenshot Thank you so much!! Means a lot!',
#      'sentiment': 0.125},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406865650484596741',
#    'key': [2021,
#     6,
#     21,
#     '1405860990999093264',
#     '35228172',
#     '1406865650484596741'],
#    'value': {'text': 'Where’s the big pineapple'},
#    'doc': {'_id': '1406865650484596741',
#     '_rev': '1-19c2262a9e95c271826c62318dcd83b8',
#     'data': {'author_id': '35228172',
#      'context_annotations': [{'domain': {'id': '71',
#         'name': 'Video Game',
#         'description': 'A video game like Overwatch'},
#        'entity': {'id': '1404138543773933568',
#         'name': 'Microsoft Flight Simulator'}}],
#      'conversation_id': '1405860990999093264',
#      'created_at': '2021-06-21T06:44:44.000Z',
#      'entities': {'mentions': [{'start': 0,
#         'end': 10,
#         'username': 'coalabr14'},
#        {'start': 11, 'end': 19, 'username': 'Serrels'},
#        {'start': 20, 'end': 33, 'username': 'MSFSofficial'},
#        {'start': 34, 'end': 46, 'username': 'AsoboStudio'},
#        {'start': 47, 'end': 55, 'username': 'lillhoo'},
#        {'start': 56, 'end': 69, 'username': 'GamerGram_GG'},
#        {'start': 70, 'end': 83, 'username': 'ThePhotoMode'},
#        {'start': 84, 'end': 100, 'username': '_GameScreenshot'},
#        {'start': 101, 'end': 111, 'username': 'NvidiaANZ'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@coalabr14 @Serrels @MSFSofficial @AsoboStudio @lillhoo @GamerGram_GG @ThePhotoMode @_GameScreenshot @NvidiaANZ Where’s the big pineapple',
#      'sentiment': 0.06666666666666667},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406923768878960649',
#    'key': [2021,
#     6,
#     21,
#     '1405861219370782721',
#     '709718136',
#     '1406923768878960649'],
#    'value': {'text': '👏🏼👏🏼👏🏼👏🏼👏🏼😘'},
#    'doc': {'_id': '1406923768878960649',
#     '_rev': '1-039a682f38aec58e6896e5ee963db041',
#     'data': {'author_id': '709718136',
#      'conversation_id': '1405861219370782721',
#      'created_at': '2021-06-21T10:35:40.000Z',
#      'entities': {'mentions': [{'start': 0,
#         'end': 10,
#         'username': 'rociomag3'},
#        {'start': 11, 'end': 27, 'username': 'socorro49046006'}]},
#      'geo': {},
#      'lang': 'und',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@rociomag3 @socorro49046006 👏🏼👏🏼👏🏼👏🏼👏🏼😘',
#      'sentiment': {'score': 0,
#       'comparative': 0,
#       'calculation': [],
#       'tokens': ['@rociomag3', '@socorro49046006', '👏🏼👏🏼👏🏼👏🏼👏🏼😘'],
#       'words': [],
#       'positive': [],
#       'negative': []}},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406877875391721475',
#    'key': [2021,
#     6,
#     21,
#     '1405861333493596162',
#     '1381925110295142403',
#     '1406877875391721475'],
#    'value': {'text': 'They look beautiful, the color is amazing. They look very kissable 🥰'},
#    'doc': {'_id': '1406877875391721475',
#     '_rev': '1-e4bd5f2bbaf4d19c43c8db603b877847',
#     'data': {'author_id': '1381925110295142403',
#      'conversation_id': '1405861333493596162',
#      'created_at': '2021-06-21T07:33:18.000Z',
#      'entities': {'mentions': [{'start': 0,
#         'end': 11,
#         'username': 'jenhollyof'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@jenhollyof They look beautiful, the color is amazing. They look very kissable 🥰',
#      'sentiment': 0.5384615384615384},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406821531578077190',
#    'key': [2021,
#     6,
#     21,
#     '1405862718222090241',
#     '1386293675081093121',
#     '1406821531578077190'],
#    'value': {'text': 'Any chance of reviewing n’s small brother ?'},
#    'doc': {'_id': '1406821531578077190',
#     '_rev': '1-ddbd5c697b171f07ffff34b2eb74746d',
#     'data': {'author_id': '1386293675081093121',
#      'context_annotations': [{'domain': {'id': '45',
#         'name': 'Brand Vertical',
#         'description': 'Top level entities that describe a Brands industry'},
#        'entity': {'id': '781974596148793345', 'name': 'Business & finance'}},
#       {'domain': {'id': '46',
#         'name': 'Brand Category',
#         'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#        'entity': {'id': '781974596794716162', 'name': 'Financial services'}},
#       {'domain': {'id': '47',
#         'name': 'Brand',
#         'description': 'Brands and Companies'},
#        'entity': {'id': '1007360414114435072',
#         'name': 'Bitcoin cryptocurrency',
#         'description': 'Bitcoin Cryptocurrency'}},
#       {'domain': {'id': '65',
#         'name': 'Interests and Hobbies Vertical',
#         'description': 'Top level interests and hobbies groupings, like Food or Travel'},
#        'entity': {'id': '847529762566230016',
#         'name': 'Business and finance',
#         'description': 'Business'}},
#       {'domain': {'id': '66',
#         'name': 'Interests and Hobbies Category',
#         'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'},
#        'entity': {'id': '847888632711061504',
#         'name': 'Personal finance',
#         'description': 'Personal finance'}},
#       {'domain': {'id': '66',
#         'name': 'Interests and Hobbies Category',
#         'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'},
#        'entity': {'id': '913142676819648512',
#         'name': 'Cryptocurrencies',
#         'description': 'Cryptocurrency'}}],
#      'conversation_id': '1405862718222090241',
#      'created_at': '2021-06-21T03:49:25.000Z',
#      'entities': {'annotations': [{'start': 37,
#         'end': 43,
#         'probability': 0.3163,
#         'type': 'Organization',
#         'normalized_text': 'Bitcoin'}],
#       'cashtags': [{'start': 61, 'end': 65, 'tag': 'dfi'}],
#       'mentions': [{'start': 0, 'end': 12, 'username': 'BTC_Archive'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@BTC_Archive Any chance of reviewing Bitcoin’s small brother $dfi ?',
#      'sentiment': 0.2},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406944199535075328',
#    'key': [2021,
#     6,
#     21,
#     '1405862976523948035',
#     '46844177',
#     '1406944199535075328'],
#    'value': {'text': "Thank you 💞 I'd gladly swap some weather with you, not a huge fan of winter 😑"},
#    'doc': {'_id': '1406944199535075328',
#     '_rev': '1-68a4bbf808e91265280a828606bf6544',
#     'data': {'author_id': '46844177',
#      'context_annotations': [{'domain': {'id': '65',
#         'name': 'Interests and Hobbies Vertical',
#         'description': 'Top level interests and hobbies groupings, like Food or Travel'},
#        'entity': {'id': '854692455005921281',
#         'name': 'Science',
#         'description': 'Science'}},
#       {'domain': {'id': '66',
#         'name': 'Interests and Hobbies Category',
#         'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'},
#        'entity': {'id': '857083369514876928',
#         'name': 'Weather',
#         'description': 'Weather'}}],
#      'conversation_id': '1405862976523948035',
#      'created_at': '2021-06-21T11:56:51.000Z',
#      'entities': {'mentions': [{'start': 0,
#         'end': 10,
#         'username': 'szonjakun'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': "@szonjakun Thank you 💞 I'd gladly swap some weather with you, not a huge fan of winter 😑",
#      'sentiment': 0.3888888888888889},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406821324895313920',
#    'key': [2021,
#     6,
#     21,
#     '1405863442653851653',
#     '725627887265546240',
#     '1406821324895313920'],
#    'value': {'text': 'unroll plz'},
#    'doc': {'_id': '1406821324895313920',
#     '_rev': '1-b5e3460a28a3d1df413055e1a444bf9f',
#     'data': {'author_id': '725627887265546240',
#      'conversation_id': '1405863442653851653',
#      'created_at': '2021-06-21T03:48:35.000Z',
#      'entities': {'mentions': [{'start': 0,
#         'end': 14,
#         'username': 'robinmonotti2'},
#        {'start': 15, 'end': 31, 'username': 'threadreaderapp'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 1,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@robinmonotti2 @threadreaderapp  unroll plz',
#      'sentiment': 0},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406940282344468484',
#    'key': [2021,
#     6,
#     21,
#     '1405865060354998281',
#     '1118528233580814337',
#     '1406940282344468484'],
#    'value': {'text': 'so good!'},
#    'doc': {'_id': '1406940282344468484',
#     '_rev': '1-1bfc785f29cb1cb9d86e302cedfe3e6e',
#     'data': {'author_id': '1118528233580814337',
#      'conversation_id': '1405865060354998281',
#      'created_at': '2021-06-21T11:41:17.000Z',
#      'entities': {'mentions': [{'start': 0,
#         'end': 13,
#         'username': 'alwaysfnatic'},
#        {'start': 14, 'end': 20, 'username': 'wax1s'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@alwaysfnatic @wax1s so good!',
#      'sentiment': 0.75},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406843293585997825',
#    'key': [2021,
#     6,
#     21,
#     '1405865472172728324',
#     '1092202371474550784',
#     '1406843293585997825'],
#    'value': {'text': 'Also with you, y!'},
#    'doc': {'_id': '1406843293585997825',
#     '_rev': '1-938556405bddc34d6c62a0686df96a88',
#     'data': {'author_id': '1092202371474550784',
#      'conversation_id': '1405865472172728324',
#      'created_at': '2021-06-21T05:15:53.000Z',
#      'entities': {'annotations': [{'start': 251,
#         'end': 255,
#         'probability': 0.98,
#         'type': 'Person',
#         'normalized_text': 'Peggy'}],
#       'mentions': [{'start': 0, 'end': 11, 'username': 'PeggyBodde'},
#        {'start': 12, 'end': 27, 'username': 'InstaEncourage'},
#        {'start': 28, 'end': 39, 'username': 'onthewaybg'},
#        {'start': 40, 'end': 56, 'username': 'BeckySm80910388'},
#        {'start': 57, 'end': 70, 'username': 'StaceyPardoe'},
#        {'start': 71, 'end': 81, 'username': 'YMMauthor'},
#        {'start': 82, 'end': 98, 'username': 'BethanyMcIlrath'},
#        {'start': 99, 'end': 111, 'username': 'MelanieRedd'},
#        {'start': 112, 'end': 128, 'username': 'BlessingCounter'},
#        {'start': 129, 'end': 142, 'username': 'JesusChasing'},
#        {'start': 143, 'end': 158, 'username': 'thiessen_amber'},
#        {'start': 159, 'end': 172, 'username': 'ChristelOwoo'},
#        {'start': 173, 'end': 188, 'username': 'JeanneTakenaka'},
#        {'start': 189, 'end': 203, 'username': 'MicheleDMorin'},
#        {'start': 204, 'end': 220, 'username': 'serenityinsuff1'},
#        {'start': 221, 'end': 235, 'username': 'DebbieWWilson'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@PeggyBodde @InstaEncourage @onthewaybg @BeckySm80910388 @StaceyPardoe @YMMauthor @BethanyMcIlrath @MelanieRedd @BlessingCounter @JesusChasing @thiessen_amber @ChristelOwoo @JeanneTakenaka @MicheleDMorin @serenityinsuff1 @DebbieWWilson Also with you, Peggy!',
#      'sentiment': 0},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406858713785278466',
#    'key': [2021,
#     6,
#     21,
#     '1405865894878715906',
#     '1357015702658375682',
#     '1406858713785278466'],
#    'value': {'text': 'Hell yeah man'},
#    'doc': {'_id': '1406858713785278466',
#     '_rev': '1-7cb9f8b2af8d2d3949ea87811566651a',
#     'data': {'author_id': '1357015702658375682',
#      'conversation_id': '1405865894878715906',
#      'created_at': '2021-06-21T06:17:10.000Z',
#      'entities': {'mentions': [{'start': 0,
#         'end': 12,
#         'username': 'Max21393393'},
#        {'start': 13, 'end': 29, 'username': 'EliteEsOfficial'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@Max21393393 @EliteEsOfficial Hell yeah man',
#      'sentiment': -0.6},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406884684093554695',
#    'key': [2021,
#     6,
#     21,
#     '1405866208168140806',
#     '14290644',
#     '1406884684093554695'],
#    'value': {'text': 'Thanks for the inclusion of my new single, Gee that’s really kind of you 🙏💛🤗'},
#    'doc': {'_id': '1406884684093554695',
#     '_rev': '1-709d1c6f07ca665c79b7e1448d6d74cb',
#     'data': {'author_id': '14290644',
#      'conversation_id': '1405866208168140806',
#      'created_at': '2021-06-21T08:00:21.000Z',
#      'entities': {'mentions': [{'start': 0,
#         'end': 14,
#         'username': 'animal_revolt'},
#        {'start': 15, 'end': 31, 'username': 'GkoumasNastazio'},
#        {'start': 32, 'end': 47, 'username': 'SkylarNevaeh01'},
#        {'start': 48, 'end': 64, 'username': 'johnmichiemusic'},
#        {'start': 65, 'end': 77, 'username': 'riwolfmusic'},
#        {'start': 78, 'end': 89, 'username': 'lewcamusic'},
#        {'start': 90, 'end': 106, 'username': 'WretchedPuppets'},
#        {'start': 107, 'end': 118, 'username': 'tubeamp101'},
#        {'start': 119, 'end': 126, 'username': 'rapz90'},
#        {'start': 127, 'end': 135, 'username': 'BlyssLv'},
#        {'start': 136, 'end': 147, 'username': 'UsmicDecan'},
#        {'start': 148, 'end': 162, 'username': 'HardlandRocks'},
#        {'start': 163, 'end': 172, 'username': 'enimatik'},
#        {'start': 173, 'end': 186, 'username': 'GwillamBarge'},
#        {'start': 187, 'end': 201, 'username': 'artblockmusic'},
#        {'start': 202, 'end': 212, 'username': 'La_Vivas_'},
#        {'start': 213, 'end': 223, 'username': 'PericsThe'},
#        {'start': 271, 'end': 285, 'username': 'animal_revolt'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@animal_revolt @GkoumasNastazio @SkylarNevaeh01 @johnmichiemusic @riwolfmusic @lewcamusic @WretchedPuppets @tubeamp101 @rapz90 @BlyssLv @UsmicDecan @HardlandRocks @enimatik @GwillamBarge @artblockmusic @La_Vivas_ @PericsThe Thanks for the inclusion of my new single, Gee @animal_revolt that’s really kind of you 🙏💛🤗',
#      'sentiment': 0.1111111111111111},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406892730098147330',
#    'key': [2021,
#     6,
#     21,
#     '1405866796020809730',
#     '1334815774574141440',
#     '1406892730098147330'],
#    'value': {'text': 'Welcome to the fray and following!! 🥳� Ij'},
#    'doc': {'_id': '1406892730098147330',
#     '_rev': '1-081494945463b8bb5e6f14d6fe631c96',
#     'data': {'author_id': '1334815774574141440',
#      'conversation_id': '1405866796020809730',
#      'created_at': '2021-06-21T08:32:20.000Z',
#      'entities': {'mentions': [{'start': 0,
#         'end': 10,
#         'username': 'NunyaB127'},
#        {'start': 11, 'end': 22, 'username': 'Louisa1496'},
#        {'start': 23, 'end': 34, 'username': 'BBella1518'},
#        {'start': 35, 'end': 51, 'username': 'ubiquitous_miss'}],
#       'urls': [{'start': 91,
#         'end': 114,
#         'url': 'https://t.co/kYwixPUJIj',
# ...
#      'conversation_id': '1406056135468138496',
#      'created_at': '2021-06-21T05:12:26.000Z',
#      'entities': {'mentions': [{'start': 0,
#         'end': 11,
#         'username': 'AlanBixter'},
#        {'start': 12, 'end': 26, 'username': 'richard_jayne'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@AlanBixter @richard_jayne Everyone be needing moderna before too long. Stupidity reigns supreme.',
#      'sentiment': 0.07692307692307693},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406784136841371650',
#    'key': [2021,
#     6,
#     21,
#     '1406056144301404166',
#     '943105250189180928',
#     '1406784136841371650'],
#    'value': {'text': 'You got issues 💀'},
#    'doc': {'_id': '1406784136841371650',
#     '_rev': '1-d8fc09bff27ced6768bfb44572ef8896',
#     'data': {'author_id': '943105250189180928',
#      'conversation_id': '1406056144301404166',
#      'created_at': '2021-06-21T01:20:49.000Z',
#      'entities': {'mentions': [{'start': 0,
#         'end': 15,
#         'username': 'sienna31579076'},
#        {'start': 16, 'end': 30, 'username': 'bluefaceniloc'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@sienna31579076 @bluefaceniloc You got issues 💀',
#      'sentiment': -0.3333333333333333},
#     'matching_rules': [{'id': 1405794688146182100,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406912037599412224',
#    'key': [2021,
#     6,
#     21,
#     '1406056424409649153',
#     '1260182013857820672',
#     '1406912037599412224'],
#    'value': {'text': 'Welcome to Grab claim! or . the maximum compensation quickly by Uploading your documents on our app! App Store: . y:'},
#    'doc': {'_id': '1406912037599412224',
#     '_rev': '1-c5bae43ce780900865a315c7cc5a89b2',
#     'data': {'author_id': '1260182013857820672',
#      'context_annotations': [{'domain': {'id': '46',
#         'name': 'Brand Category',
#         'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#        'entity': {'id': '781974596752842752', 'name': 'Services'}},
#       {'domain': {'id': '47',
#         'name': 'Brand',
#         'description': 'Brands and Companies'},
#        'entity': {'id': '10026364281', 'name': 'Apple'}},
#       {'domain': {'id': '47',
#         'name': 'Brand',
#         'description': 'Brands and Companies'},
#        'entity': {'id': '10026378521', 'name': 'Google '}},
#       {'domain': {'id': '48',
#         'name': 'Product',
#         'description': 'Products created by Brands.  Examples: Ford Explorer, Apple iPhone.'},
#        'entity': {'id': '10053298770',
#         'name': 'Apple App Store',
#         'description': 'Apple App Store'}},
#       {'domain': {'id': '48',
#         'name': 'Product',
#         'description': 'Products created by Brands.  Examples: Ford Explorer, Apple iPhone.'},
#        'entity': {'id': '1395474411180892160',
#         'name': 'Google brand conversation'}},
#       {'domain': {'id': '46',
#         'name': 'Brand Category',
#         'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#        'entity': {'id': '781974596752842752', 'name': 'Services'}},
#       {'domain': {'id': '47',
#         'name': 'Brand',
#         'description': 'Brands and Companies'},
#        'entity': {'id': '10026378521', 'name': 'Google '}},
#       {'domain': {'id': '47',
#         'name': 'Brand',
#         'description': 'Brands and Companies'},
#        'entity': {'id': '10046487168', 'name': 'App Store'}},
#       {'domain': {'id': '48',
#         'name': 'Product',
#         'description': 'Products created by Brands.  Examples: Ford Explorer, Apple iPhone.'},
#        'entity': {'id': '10028889887', 'name': 'Google Play'}}],
#      'conversation_id': '1406056424409649153',
#      'created_at': '2021-06-21T09:49:03.000Z',
#      'entities': {'annotations': [{'start': 183,
#         'end': 193,
#         'probability': 0.5193,
#         'type': 'Product',
#         'normalized_text': 'Google Play'}],
#       'hashtags': [{'start': 34, 'end': 41, 'tag': 'flight'},
#        {'start': 42, 'end': 52, 'tag': 'cancelled'},
#        {'start': 56, 'end': 64, 'tag': 'delayed'},
#        {'start': 66, 'end': 72, 'tag': 'claim'}],
#       'mentions': [{'start': 0, 'end': 10, 'username': 'tooweevil'}],
#       'urls': [{'start': 158,
#         'end': 181,
#         'url': 'https://t.co/mvLD78EJmM',
#         'expanded_url': 'https://apple.co/3aeLM6l',
#         'display_url': 'apple.co/3aeLM6l',
#         'images': [{'url': 'https://pbs.twimg.com/news_img/1405087801943552003/XEA6FPuI?format=png&name=orig',
#           'width': 600,
#           'height': 600},
#          {'url': 'https://pbs.twimg.com/news_img/1405087801943552003/XEA6FPuI?format=png&name=150x150',
#           'width': 150,
#           'height': 150}],
#         'status': 200,
#         'title': '\u200eGrabClaim',
#         'description': '\u200eTravel is fun! But sometimes, things go wrong, leaving you with a bitter taste in your mouth. Moreover, many travellers often may not know that you have rights as a consumer. And for those passengers that DO know their rights, the entire process of determining what exactly are their rights or compen…',
#         'unwound_url': 'https://apps.apple.com/in/app/grabclaim/id1494504616'},
#        {'start': 196,
#         'end': 219,
#         'url': 'https://t.co/ga8V5g6zLt',
#         'expanded_url': 'https://play.google.com/store/apps/details?id=com.grabclaim',
#         'display_url': 'play.google.com/store/apps/det…',
#         'images': [{'url': 'https://pbs.twimg.com/news_img/1405564339273170946/feUb9YUu?format=png&name=orig',
#           'width': 600,
#           'height': 300},
#          {'url': 'https://pbs.twimg.com/news_img/1405564339273170946/feUb9YUu?format=png&name=150x150',
#           'width': 150,
#           'height': 150}],
#         'status': 200,
#         'title': 'Grab Claim - Apps on Google Play',
#         'description': 'Providing service quality and standing for the rights of the traveling consumer.',
#         'unwound_url': 'https://play.google.com/store/apps/details?id=com.grabclaim'},
#        {'start': 220,
#         'end': 243,
#         'url': 'https://t.co/MkTEwtTlNQ',
#         'expanded_url': 'https://twitter.com/Suzan28626343/status/1406912037599412224/photo/1',
#         'display_url': 'pic.twitter.com/MkTEwtTlNQ'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@tooweevil Welcome to Grab claim! #flight #cancelled or #delayed .#claim the maximum compensation quickly by Uploading your documents on our app! App  Store: https://t.co/mvLD78EJmM .Google Play: https://t.co/ga8V5g6zLt https://t.co/MkTEwtTlNQ',
#      'sentiment': 0},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406854836033703938',
#    'key': [2021,
#     6,
#     21,
#     '1406056948340903941',
#     '936131277366837253',
#     '1406854836033703938'],
#    'value': {'text': 'I like the way you think 🧐'},
#    'doc': {'_id': '1406854836033703938',
#     '_rev': '1-57cb69770542800c1d48384c0f37f342',
#     'data': {'author_id': '936131277366837253',
#      'conversation_id': '1406056948340903941',
#      'created_at': '2021-06-21T06:01:45.000Z',
#      'entities': {'mentions': [{'start': 0,
#         'end': 13,
#         'username': 'RainMorgan33'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@RainMorgan33 I like the way you think 🧐',
#      'sentiment': 0.25},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406866161539555330',
#    'key': [2021,
#     6,
#     21,
#     '1406056948340903941',
#     '936131277366837253',
#     '1406866161539555330'],
#    'value': {'text': "I've actually been asked to come I n many times, just noone wants to pay the deposit to get me there 😜"},
#    'doc': {'_id': '1406866161539555330',
#     '_rev': '1-7b7f39552c87a530dd52d0de0304a0ee',
#     'data': {'author_id': '936131277366837253',
#      'conversation_id': '1406056948340903941',
#      'created_at': '2021-06-21T06:46:45.000Z',
#      'entities': {'annotations': [{'start': 48,
#         'end': 53,
#         'probability': 0.5548,
#         'type': 'Person',
#         'normalized_text': 'Darwin'}],
#       'mentions': [{'start': 0, 'end': 12, 'username': 'Paul4morgan'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': "@Paul4morgan I've actually been asked to come I Darwin many times, just noone wants to pay the deposit to get me there 😜",
#      'sentiment': 0.043478260869565216},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406854932775374848',
#    'key': [2021,
#     6,
#     21,
#     '1406057414604980230',
#     '22308312',
#     '1406854932775374848'],
#    'value': {'text': 'Wouldn’t be for her journalistic skills, that’s for sure'},
#    'doc': {'_id': '1406854932775374848',
#     '_rev': '1-a101efef288a69a95cc1805c80ca8392',
#     'data': {'author_id': '22308312',
#      'conversation_id': '1406057414604980230',
#      'created_at': '2021-06-21T06:02:08.000Z',
#      'entities': {'mentions': [{'start': 0,
#         'end': 11,
#         'username': 'MixtUpMixy'},
#        {'start': 12, 'end': 24, 'username': 'adamajacoby'},
#        {'start': 25, 'end': 40, 'username': 'sophieelsworth'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@MixtUpMixy @adamajacoby @sophieelsworth Wouldn’t be for her journalistic skills, that’s for sure',
#      'sentiment': 0},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406973646577438723',
#    'key': [2021,
#     6,
#     21,
#     '1406057579659153409',
#     '1102910439015370752',
#     '1406973646577438723'],
#    'value': {'text': 'I went there for a weeding a few months ago. There is nothing secret in the slightest. Its a nice establishment for any celebration.'},
#    'doc': {'_id': '1406973646577438723',
#     '_rev': '1-fcc55d377569d9adad6e9ffde3e153b1',
#     'data': {'author_id': '1102910439015370752',
#      'conversation_id': '1406057579659153409',
#      'created_at': '2021-06-21T13:53:52.000Z',
#      'entities': {'mentions': [{'start': 0,
#         'end': 12,
#         'username': 'CaroDiRusso'},
#        {'start': 13, 'end': 28, 'username': 'westaustralian'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@CaroDiRusso @westaustralian I went there for a weeding a few months ago. There is nothing secret in the slightest. Its a nice establishment for any celebration.',
#      'sentiment': 0.23076923076923078},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406987309690482689',
#    'key': [2021,
#     6,
#     21,
#     '1406058146934706188',
#     '60866631',
#     '1406987309690482689'],
#    'value': {'text': 'Australians don’t want to send her to a , n the r and his storm trooper n want to send her family'},
#    'doc': {'_id': '1406987309690482689',
#     '_rev': '1-5d3d009eae0f57cc9a3efeef64056c01',
#     'data': {'author_id': '60866631',
#      'context_annotations': [{'domain': {'id': '10',
#         'name': 'Person',
#         'description': 'Named people in the world like Nelson Mandela'},
#        'entity': {'id': '1043141608147841024',
#         'name': 'Scott Morrison',
#         'description': 'Prime Minister of Australia, Scott Morrison'}},
#       {'domain': {'id': '35',
#         'name': 'Politician',
#         'description': 'Politicians in the world, like Joe Biden'},
#        'entity': {'id': '1043141608147841024',
#         'name': 'Scott Morrison',
#         'description': 'Prime Minister of Australia, Scott Morrison'}}],
#      'conversation_id': '1406058146934706188',
#      'created_at': '2021-06-21T14:48:09.000Z',
#      'entities': {'annotations': [{'start': 44,
#         'end': 52,
#         'probability': 0.4641,
#         'type': 'Place',
#         'normalized_text': 'Sri Lanka'},
#        {'start': 56,
#         'end': 69,
#         'probability': 0.996,
#         'type': 'Person',
#         'normalized_text': 'Scott Morrison'},
#        {'start': 75,
#         'end': 88,
#         'probability': 0.7409,
#         'type': 'Person',
#         'normalized_text': 'Prime Minister'},
#        {'start': 112,
#         'end': 123,
#         'probability': 0.9973,
#         'type': 'Person',
#         'normalized_text': 'Peter Dutton'}],
#       'mentions': [{'start': 0, 'end': 5, 'username': 'cnni'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@cnni Australians don’t want to send her to Sri Lanka , Scott Morrison the Prime Minister and his storm trooper Peter Dutton want to send her family',
#      'sentiment': 0.07692307692307693},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1406955275370729480',
#    'key': [2021,
#     6,
#     21,
#     '1406058213787701249',
#     '122395798',
#     '1406955275370729480'],
#    'value': {'text': 'So cute!'},
#    'doc': {'_id': '1406955275370729480',
#     '_rev': '1-5b14e6ffa418a56e5b8f5cdb18ccdaf7',
#     'data': {'author_id': '122395798',
#      'conversation_id': '1406058213787701249',
#      'created_at': '2021-06-21T12:40:52.000Z',
#      'entities': {'mentions': [{'start': 0,
#         'end': 13,
#         'username': 'QuietScrappy'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@QuietScrappy So cute!',
#      'sentiment': 0.6666666666666666},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {'id': '1407119087780565000',
#    'key': [2021,
#     6,
#     21,
#     '1406059272568553472',
#     '1404434184',
#     '1407119087780565000'],
#    'value': {'text': 'Because if they are wrong the s will be all over it. If they are investigating they won’t let us know.'},
#    'doc': {'_id': '1407119087780565000',
#     '_rev': '1-4130137cc4fbda9e80277775303c2e0a',
#     'data': {'author_id': '1404434184',
#      'conversation_id': '1406059272568553472',
#      'created_at': '2021-06-21T23:31:48.000Z',
#      'entities': {'annotations': [{'start': 74,
#         'end': 84,
#         'probability': 0.7587,
#         'type': 'Organization',
#         'normalized_text': 'republicans'}],
#       'mentions': [{'start': 0, 'end': 16, 'username': 'GrassrootsSpeak'},
#        {'start': 17, 'end': 28, 'username': 'kchernecky'},
#        {'start': 29, 'end': 43, 'username': 'JJofromcocomo'}]},
#      'geo': {},
#      'lang': 'en',
#      'public_metrics': {'retweet_count': 0,
#       'reply_count': 0,
#       'like_count': 0,
#       'quote_count': 0},
#      'text': '@GrassrootsSpeak @kchernecky @JJofromcocomo Because if they are wrong the republicans will be all over it. If they are investigating they won’t let us know.',
#      'sentiment': -0.08333333333333333},
#     'matching_rules': [{'id': 1406789634793697300,
#       'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}},
#   {}]}

# %%
# Ensure 'created_at' is a datetime object and create new columns for analysis
df['created_at'] = pd.to_datetime(df['created_at'])
df['hour'] = df['created_at'].dt.hour
df['date'] = df['created_at'].dt.date

# Group by hour to find the happiest and most active hour
hourly_sentiment = df.groupby('hour')['sentiment'].mean().idxmax()
hourly_activity = df.groupby('hour').size().idxmax()

# Group by date to find the happiest and most active day
daily_sentiment = df.groupby('date')['sentiment'].mean().idxmax()
daily_activity = df.groupby('date').size().idxmax()

print(f"The happiest hour ever: {hourly_sentiment}:00")
print(f"The most active hour ever: {hourly_activity}:00")
print(f"The happiest day ever: {daily_sentiment}")
print(f"The most active day ever: {daily_activity}")

# %%
import json
from collections import defaultdict
from dateutil import parser
import time

# start = time.localtime()
# Load the JSON data
with open('data/twitter-50mb.json') as f:
    data = json.load(f)

# Extract relevant fields and calculate sentiment scores
tweets = []
for tweet in data['rows']:
    # if 'value' not in tweet:
    #     continue
    if 'doc' not in tweet:
        continue
    if 'sentiment' not in tweet['doc']['data']:
        continue
    # created_at = datetime.fromisoformat(tweet['doc']['data']['created_at'])
    created_at = parser.parse(tweet['doc']['data']['created_at'])
    sentiment_score = tweet['doc']['data']['sentiment']
    if isinstance(sentiment_score, dict):
        sentiment_score = sentiment_score['score']
    # print(sentiment_score)
    tweets.append({'created_at': created_at, 'sentiment_score': sentiment_score})

tweets_df = pd.DataFrame(tweets)
# Convert the created_at column to datetime
tweets_df['created_at'] = pd.to_datetime(tweets_df['created_at'])

# Extract the hour and day from the created_at column
tweets_df['hour'] = tweets_df['created_at'].dt.hour
tweets_df['day'] = tweets_df['created_at'].dt.date

happiest_hour = tweets_df.groupby('hour')['sentiment_score'].sum().idxmax()
happiest_day = tweets_df.groupby('day')['sentiment_score'].sum().idxmax()
most_active_hour = tweets_df['hour'].value_counts().idxmax()
most_active_day = tweets_df['day'].value_counts().idxmax()

# end = time.localtime()

# print(end - start)
print(f"Happiest hour: {happiest_hour}")
print(f"Happiest day: {happiest_day}")
print(f"Most active hour: {most_active_hour}")
print(f"Most active day: {most_active_day}")
# Out:
# Happiest hour: 2
# Happiest day: 2021-06-21
# Most active hour: 1
# Most active day: 2021-06-21

# %%
tweets
# Out:
# [{'created_at': datetime.datetime(2021, 6, 21, 3, 18, 59, tzinfo=tzutc()),
#   'sentiment_score': 0.7142857142857143},
#  {'created_at': datetime.datetime(2021, 6, 21, 3, 21, 5, tzinfo=tzutc()),
#   'sentiment_score': 0.36363636363636365},
#  {'created_at': datetime.datetime(2021, 6, 21, 10, 23, 48, tzinfo=tzutc()),
#   'sentiment_score': 0},
#  {'created_at': datetime.datetime(2021, 6, 21, 10, 56, 40, tzinfo=tzutc()),
#   'sentiment_score': 0.25},
#  {'created_at': datetime.datetime(2021, 6, 21, 11, 9, 17, tzinfo=tzutc()),
#   'sentiment_score': 0},
#  {'created_at': datetime.datetime(2021, 6, 21, 23, 36, 59, tzinfo=tzutc()),
#   'sentiment_score': -0.09523809523809523},
#  {'created_at': datetime.datetime(2021, 6, 21, 4, 14, 46, tzinfo=tzutc()),
#   'sentiment_score': 0.3},
#  {'created_at': datetime.datetime(2021, 6, 21, 0, 46, 21, tzinfo=tzutc()),
#   'sentiment_score': 0.09090909090909091},
#  {'created_at': datetime.datetime(2021, 6, 21, 14, 2, 21, tzinfo=tzutc()),
#   'sentiment_score': 0.08333333333333333},
#  {'created_at': datetime.datetime(2021, 6, 21, 2, 47, 55, tzinfo=tzutc()),
#   'sentiment_score': -0.23076923076923078},
#  {'created_at': datetime.datetime(2021, 6, 21, 1, 13, 14, tzinfo=tzutc()),
#   'sentiment_score': -0.125},
#  {'created_at': datetime.datetime(2021, 6, 21, 6, 50, 44, tzinfo=tzutc()),
#   'sentiment_score': -0.1111111111111111},
#  {'created_at': datetime.datetime(2021, 6, 21, 6, 51, 29, tzinfo=tzutc()),
#   'sentiment_score': 0},
#  {'created_at': datetime.datetime(2021, 6, 21, 10, 40, 26, tzinfo=tzutc()),
#   'sentiment_score': -0.10526315789473684},
#  {'created_at': datetime.datetime(2021, 6, 21, 11, 58, 58, tzinfo=tzutc()),
#   'sentiment_score': 0.038461538461538464},
#  {'created_at': datetime.datetime(2021, 6, 21, 0, 39, 55, tzinfo=tzutc()),
#   'sentiment_score': -0.11764705882352941},
#  {'created_at': datetime.datetime(2021, 6, 21, 12, 3, 38, tzinfo=tzutc()),
#   'sentiment_score': 0.19230769230769232},
#  {'created_at': datetime.datetime(2021, 6, 21, 9, 51, 22, tzinfo=tzutc()),
#   'sentiment_score': 1},
#  {'created_at': datetime.datetime(2021, 6, 21, 7, 37, 37, tzinfo=tzutc()),
#   'sentiment_score': -0.13333333333333333},
#  {'created_at': datetime.datetime(2021, 6, 21, 2, 35, 16, tzinfo=tzutc()),
#   'sentiment_score': 0.1},
#  {'created_at': datetime.datetime(2021, 6, 21, 7, 47, 23, tzinfo=tzutc()),
#   'sentiment_score': -0.023809523809523808},
#  {'created_at': datetime.datetime(2021, 6, 21, 10, 11, 28, tzinfo=tzutc()),
#   'sentiment_score': 0.125},
#  {'created_at': datetime.datetime(2021, 6, 21, 6, 44, 44, tzinfo=tzutc()),
#   'sentiment_score': 0.06666666666666667},
#  {'created_at': datetime.datetime(2021, 6, 21, 10, 35, 40, tzinfo=tzutc()),
#   'sentiment_score': {'score': 0,
#    'comparative': 0,
#    'calculation': [],
#    'tokens': ['@rociomag3', '@socorro49046006', '👏🏼👏🏼👏🏼👏🏼👏🏼😘'],
#    'words': [],
#    'positive': [],
#    'negative': []}},
#  {'created_at': datetime.datetime(2021, 6, 21, 7, 33, 18, tzinfo=tzutc()),
#   'sentiment_score': 0.5384615384615384},
#  {'created_at': datetime.datetime(2021, 6, 21, 3, 49, 25, tzinfo=tzutc()),
#   'sentiment_score': 0.2},
#  {'created_at': datetime.datetime(2021, 6, 21, 11, 56, 51, tzinfo=tzutc()),
#   'sentiment_score': 0.3888888888888889},
#  {'created_at': datetime.datetime(2021, 6, 21, 3, 48, 35, tzinfo=tzutc()),
#   'sentiment_score': 0},
#  {'created_at': datetime.datetime(2021, 6, 21, 11, 41, 17, tzinfo=tzutc()),
#   'sentiment_score': 0.75},
#  {'created_at': datetime.datetime(2021, 6, 21, 5, 15, 53, tzinfo=tzutc()),
#   'sentiment_score': 0},
#  {'created_at': datetime.datetime(2021, 6, 21, 6,

#  {'created_at': datetime.datetime(2021, 6, 21, 4, 5, 18, tzinfo=tzutc()),
#   'sentiment_score': 0},
#  {'created_at': datetime.datetime(2021, 6, 21, 1, 45, 46, tzinfo=tzutc()),
#   'sentiment_score': -0.14545454545454545},
#  {'created_at': datetime.datetime(2021, 6, 21, 1, 47, 55, tzinfo=tzutc()),
#   'sentiment_score': 0},
#  {'created_at': datetime.datetime(2021, 6, 21, 7, 33, 49, tzinfo=tzutc()),
#   'sentiment_score': 0.01818181818181818},
#  {'created_at': datetime.datetime(2021, 6, 21, 7, 39, 54, tzinfo=tzutc()),
#   'sentiment_score': 0.01818181818181818},
# ...
#  {'created_at': datetime.datetime(2021, 6, 21, 8, 20, 45, tzinfo=tzutc()),
#   'sentiment_score': 0},
#  {'created_at': datetime.datetime(2021, 6, 21, 12, 36, 49, tzinfo=tzutc()),
#   'sentiment_score': 0},
#  {'created_at': datetime.datetime(2021, 6, 21, 7, 20, 16, tzinfo=tzutc()),
#   'sentiment_score': 0},
#  {'created_at': datetime.datetime(2021, 6, 21, 15, 24, 26, tzinfo=tzutc()),
#   'sentiment_score': -0.2},
#  {'created_at': datetime.datetime(2021, 6, 21, 2, 47, 33, tzinfo=tzutc()),
#   'sentiment_score': 0},
#  {'created_at': datetime.datetime(2021, 6, 21, 14, 38, 6, tzinfo=tzutc()),
#   'sentiment_score': -0.5},
#  {'created_at': datetime.datetime(2021, 6, 21, 15, 4, 12, tzinfo=tzutc()),
#   'sentiment_score': 0.2903225806451613},
#  {'created_at': datetime.datetime(2021, 6, 21, 6, 7, 23, tzinfo=tzutc()),
#   'sentiment_score': -0.2222222222222222},
#  {'created_at': datetime.datetime(2021, 6, 21, 0, 44, 19, tzinfo=tzutc()),
#   'sentiment_score': 0.2857142857142857},
#  {'created_at': datetime.datetime(2021, 6, 21, 9, 44, 51, tzinfo=tzutc()),
#   'sentiment_score': -0.07692307692307693},
#  {'created_at': datetime.datetime(2021, 6, 21, 12, 52, 41, tzinfo=tzutc()),
#   'sentiment_score': 0.4},
#  {'created_at': datetime.datetime(2021, 6, 21, 21, 27, 18, tzinfo=tzutc()),
#   'sentiment_score': -0.21428571428571427},
#  {'created_at': datetime.datetime(2021, 6, 21, 1, 16, 36, tzinfo=tzutc()),
#   'sentiment_score': 0.3333333333333333},
#  {'created_at': datetime.datetime(2021, 6, 21, 11, 42, 21, tzinfo=tzutc()),
#   'sentiment_score': 0.46153846153846156},
#  {'created_at': datetime.datetime(2021, 6, 21, 5, 46, 37, tzinfo=tzutc()),
#   'sentiment_score': 0},
#  {'created_at': datetime.datetime(2021, 6, 21, 10, 42, 23, tzinfo=tzutc()),
#   'sentiment_score': -0.09433962264150944},
#  {'created_at': datetime.datetime(2021, 6, 21, 7, 41, 2, tzinfo=tzutc()),
#   'sentiment_score': 0},
#  {'created_at': datetime.datetime(2021, 6, 21, 5, 19, 45, tzinfo=tzutc()),
#   'sentiment_score': 0.8571428571428571},
#  {'created_at': datetime.datetime(2021, 6, 21, 4, 9, 4, tzinfo=tzutc()),
#   'sentiment_score': 0.2857142857142857},
#  {'created_at': datetime.datetime(2021, 6, 21, 4, 9, 56, tzinfo=tzutc()),
#   'sentiment_score': 0.5},
#  {'created_at': datetime.datetime(2021, 6, 21, 5, 21, 16, tzinfo=tzutc()),
#   'sentiment_score': 0.8},
#  {'created_at': datetime.datetime(2021, 6, 21, 1, 11, 8, tzinfo=tzutc()),
#   'sentiment_score': 0.25},
#  {'created_at': datetime.datetime(2021, 6, 21, 3, 31, 30, tzinfo=tzutc()),
#   'sentiment_score': 0},
#  {'created_at': datetime.datetime(2021, 6, 21, 16, 40, 18, tzinfo=tzutc()),
#   'sentiment_score': 0.08333333333333333},
#  {'created_at': datetime.datetime(2021, 6, 21, 4, 23, 12, tzinfo=tzutc()),
#   'sentiment_score': 0},
#  {'created_at': datetime.datetime(2021, 6, 21, 0, 41, 7, tzinfo=tzutc()),
#   'sentiment_score': 0.08695652173913043},
#  {'created_at': datetime.datetime(2021, 6, 21, 4, 27, 22, tzinfo=tzutc()),
#   'sentiment_score': -0.058823529411764705},
#  {'created_at': datetime.datetime(2021, 6, 21, 5, 28, 18, tzinfo=tzutc()),
#   'sentiment_score': 0.03636363636363636},
#  {'created_at': datetime.datetime(2021, 6, 21, 5, 37, 16, tzinfo=tzutc()),
#   'sentiment_score': 0},
#  {'created_at': datetime.datetime(2021, 6, 21, 5, 54, 28, tzinfo=tzutc()),
#   'sentiment_score': 0},
#  {'created_at': datetime.datetime(2021, 6, 21, 0, 46, 54, tzinfo=tzutc()),
#   'sentiment_score': -0.02127659574468085},
#  {'created_at': datetime.datetime(2021, 6, 21, 20, 36, 1, tzinfo=tzutc()),
#   'sentiment_score': 0.022727272727272728},
#  {'created_at': datetime.datetime(2021, 6, 21, 7, 36, 46, tzinfo=tzutc()),
#   'sentiment_score': 0.4},
#  {'created_at': datetime.datetime(2021, 6, 21, 8, 56, 59, tzinfo=tzutc()),
#   'sentiment_score': 0.7058823529411765},
#  {'created_at': datetime.datetime(2021, 6, 21, 7, 52, 16, tzinfo=tzutc()),
#   'sentiment_score': -0.1111111111111111},
#  {'created_at': datetime.datetime(2021, 6, 21, 23, 41, 8, tzinfo=tzutc()),
#   'sentiment_score': 0.2857142857142857},
#  {'created_at': datetime.datetime(2021, 6, 21, 10, 18, 48, tzinfo=tzutc()),
#   'sentiment_score': 0.2},
#  {'created_at': datetime.datetime(2021, 6, 21, 10, 36, 3, tzinfo=tzutc()),
#   'sentiment_score': {'score': 0,
#    'comparative': 0,
#    'calculation': [],
#    'tokens': ['@vlukosmp', 'https', 't', 'co', 'hf0ep68oda'],
#    'words': [],
#    'positive': [],
#    'negative': []}},
#  {'created_at': datetime.datetime(2021, 6, 21, 7, 22, 31, tzinfo=tzutc()),
#   'sentiment_score': 0.16129032258064516},
#  {'created_at': datetime.datetime(2021, 6, 21, 1, 15, 12, tzinfo=tzutc()),
#   'sentiment_score': {'score': 1,
#    'comparative': 0.16666666666666666,
#    'calculation': [{'yes': 1}],
#    'tokens': ['@elyn',
#     'cm',
#     '@gofakeyourselfm',
#     '@baronessbruck',
#     '@carolb86667602',
#     'yes'],
#    'words': ['yes'],
#    'positive': ['yes'],
#    'negative': []}},
#  {'created_at': datetime.datetime(2021, 6, 21, 8, 32, 1, tzinfo=tzutc()),
#   'sentiment_score': 0},
#  {'created_at': datetime.datetime(2021, 6, 21, 8, 32, 36, tzinfo=tzutc()),
#   'sentiment_score': 0},
#  {'created_at': datetime.datetime(2021, 6, 21, 1, 19, 23, tzinfo=tzutc()),
#   'sentiment_score': 0.09803921568627451},
#  {'created_at': datetime.datetime(2021, 6, 21, 4, 28, 51, tzinfo=tzutc()),
#   'sentiment_score': {'score': 0,
#    'comparative': 0,
#    'calculation': [],
#    'tokens': ['@cs', 'ratliff', '🙏🏻😊'],
#    'words': [],
#    'positive': [],
#    'negative': []}},
#  {'created_at': datetime.datetime(2021, 6, 21, 6,
.2},
#  {'created_at': datetime.datetime(2021, 6, 21, 7, 23, 12, tzinfo=tzutc()),
#   'sentiment_score': 0.125},
#  {'created_at': datetime.datetime(2021, 6, 21, 12, 41, 39, tzinfo=tzutc()),
#   'sentiment_score': 0},
#  {'created_at': datetime.datetime(2021, 6, 21, 6, 38, 9, tzinfo=tzutc()),
#   'sentiment_score': 0},
#  {'created_at': datetime.datetime(2021, 6, 21, 1, 47, 51, tzinfo=tzutc()),
#   'sentiment_score': 0.15789473684210525},
#  {'created_at': datetime.datetime(2021, 6, 21, 11, 25, 11, tzinfo=tzutc()),
#   'sentiment_score': -0.05555555555555555},
#  {'created_at': datetime.datetime(2021, 6, 21, 3, 28, 41, tzinfo=tzutc()),
#   'sentiment_score': 0.027777777777777776},
#  {'created_at': datetime.datetime(2021, 6, 21, 3, 18, 37, tzinfo=tzutc()),
#   'sentiment_score': -0.1875},
#  {'created_at': datetime.datetime(2021, 6, 21, 12, 50, 45, tzinfo=tzutc()),
#   'sentiment_score': -0.02857142857142857},
#  {'created_at': datetime.datetime(2021, 6, 21, 9, 42, 54, tzinfo=tzutc()),
#   'sentiment_score': 0.06666666666666667},
#  {'created_at': datetime.datetime(2021, 6, 21, 5, 21, 39, tzinfo=tzutc()),
#   'sentiment_score': -0.25},
#  {'created_at': datetime.datetime(2021, 6, 21, 9, 10, 51, tzinfo=tzutc()),
#   'sentiment_score': 0.6},
#  {'created_at': datetime.datetime(2021, 6, 21, 0, 50, 19, tzinfo=tzutc()),
#   'sentiment_score': {'score': 0,
#    'comparative': 0,
#    'calculation': [],
#    'tokens': ['@awlivv', '🔥🔥🔥🔥🔥🍑😍'],
#    'words': [],
#    'positive': [],
#    'negative': []}},
#  {'created_at': datetime.datetime(2021, 6, 21, 2, 1, 23, tzinfo=tzutc()),
#   'sentiment_score': 0},
#  {'created_at': datetime.datetime(2021, 6, 21, 2, 10, 18, tzinfo=tzutc()),
#   'sentiment_score': 0},
#  {'created_at': datetime.datetime(2021, 6, 21, 2, 11, 37, tzinfo=tzutc()),
#   'sentiment_score': 0},
#  {'created_at': datetime.datetime(2021, 6, 21, 2, 13, 7, tzinfo=tzutc()),
#   'sentiment_score': -0.25},
#  {'created_at': datetime.datetime(2021, 6, 21, 2, 22, 20, tzinfo=tzutc()),
#   'sentiment_score': 0},
#  {'created_at': datetime.datetime(2021, 6, 21, 3, 20, 28, tzinfo=tzutc()),
#   'sentiment_score': 0.375},
#  {'created_at': datetime.datetime(2021, 6, 21, 4, 34, 42, tzinfo=tzutc()),
#   'sentiment_score': -0.1875},
#  {'created_at': datetime.datetime(2021, 6, 21, 3, 1, 32, tzinfo=tzutc()),
#   'sentiment_score': 0},
#  {'created_at': datetime.datetime(2021, 6, 21, 1, 15, 55, tzinfo=tzutc()),
#   'sentiment_score': 0.0625},
#  {'created_at': datetime.datetime(2021, 6, 21, 9, 23, 52, tzinfo=tzutc()),
#   'sentiment_score': 0},
#  {'created_at': datetime.datetime(2021, 6, 21, 4, 56, 2, tzinfo=tzutc()),
#   'sentiment_score': 0},
#  {'created_at': datetime.datetime(2021, 6, 21, 11, 11, 16, tzinfo=tzutc()),
#   'sentiment_score': 0.1346153846153846},
#  {'created_at': datetime.datetime(2021, 6, 21, 8, 30, 47, tzinfo=tzutc()),
#   'sentiment_score': 0.2},
#  {'created_at': datetime.datetime(2021, 6, 21, 13, 15, 58, tzinfo=tzutc()),
#   'sentiment_score': 0},
#  {'created_at': datetime.datetime(2021, 6, 21, 13, 16, 18, tzinfo=tzutc()),
#   'sentiment_score': -0.6666666666666666},
#  {'created_at': datetime.datetime(2021, 6, 21, 18, 3, 54, tzinfo=tzutc()),
#   'sentiment_score': 0.07142857142857142},
#  {'created_at': datetime.datetime(2021, 6, 21, 5, 12, 26, tzinfo=tzutc()),
#   'sentiment_score': 0.07692307692307693},
#  {'created_at': datetime.datetime(2021, 6, 21, 1, 20, 49, tzinfo=tzutc()),
#   'sentiment_score': -0.3333333333333333},
#  {'created_at': datetime.datetime(2021, 6, 21, 9, 49, 3, tzinfo=tzutc()),
#   'sentiment_score': 0},
#  {'created_at': datetime.datetime(2021, 6, 21, 6, 1, 45, tzinfo=tzutc()),
#   'sentiment_score': 0.25},
#  {'created_at': datetime.datetime(2021, 6, 21, 6, 46, 45, tzinfo=tzutc()),
#   'sentiment_score': 0.043478260869565216},
#  {'created_at': datetime.datetime(2021, 6, 21, 6, 2, 8, tzinfo=tzutc()),
#   'sentiment_score': 0},
#  {'created_at': datetime.datetime(2021, 6, 21, 13, 53, 52, tzinfo=tzutc()),
#   'sentiment_score': 0.23076923076923078},
#  {'created_at': datetime.datetime(2021, 6, 21, 14, 48, 9, tzinfo=tzutc()),
#   'sentiment_score': 0.07692307692307693},
#  {'created_at': datetime.datetime(2021, 6, 21, 12, 40, 52, tzinfo=tzutc()),
#   'sentiment_score': 0.6666666666666666},
#  {'created_at': datetime.datetime(2021, 6, 21, 23, 31, 48, tzinfo=tzutc()),
#   'sentiment_score': -0.08333333333333333}]

# %%
# Group tweets by hour and day
tweets_by_hour = defaultdict(list)
tweets_by_day = defaultdict(list)
for tweet in tweets:
    hour = tweet['created_at'].hour
    day = tweet['created_at'].date()
    tweets_by_hour[hour].append(tweet)
    tweets_by_day[day].append(tweet)


happiest_hour = max(tweets_by_hour.items(), key=lambda x: sum(tweet['sentiment_score'] for tweet in x[1]))
happiest_day = max(tweets_by_day.items(), key=lambda x: sum(tweet['sentiment_score'] for tweet in x[1]))
most_active_hour = max(tweets_by_hour.items(), key=lambda x: len(x[1]))
most_active_day = max(tweets_by_day.items(), key=lambda x: len(x[1]))


print(f"Happiest hour: {happiest_hour[0]}")
print(f"Happiest day: {happiest_day[0]}")
print(f"Most active hour: {most_active_hour[0]}")
print(f"Most active day: {most_active_day[0]}")
# Out:
# Happiest hour: 5
# Happiest day: 2021-06-21
# Most active hour: 2
# Most active day: 2021-06-21

# %%
import json
import pandas as pd

# Load the JSON data
with open('data/twitter-1mb.json') as f:
    data = json.load(f)

# Create a list to store rows with 'doc' key
rows_with_doc = []

# Filter out rows without 'doc' key
for row in data['rows']:
    if 'doc' in row:
        rows_with_doc.append(row)

# Create a DataFrame from the rows with 'doc' key
tweets_df = pd.json_normalize(rows_with_doc)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 17
#      14         rows_with_doc.append(row)
#      16 # Create a DataFrame from the rows with 'doc' key
# ---> 17 tweets_df = pd.json_normalize(rows_with_doc, record_path=['doc'])
#
# File ~/miniconda3/envs/nlp/lib/python3.8/site-packages/pandas/io/json/_normalize.py:519, in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     516                 meta_vals[key].append(meta_val)
#     517             records.extend(recs)
# --> 519 _recursive_extract(data, record_path, {}, level=0)
#     521 result = DataFrame(records)
#     523 if record_prefix is not None:
#
# File ~/miniconda3/envs/nlp/lib/python3.8/site-packages/pandas/io/json/_normalize.py:501, in json_normalize.<locals>._recursive_extract(data, path, seen_meta, level)
#     499 else:
#     500     for obj in data:
# --> 501         recs = _pull_records(obj, path[0])
#     502         recs = [
#     503             nested_to_record(r, sep=sep, max_level=max_level)
#     504             if isinstance(r, dict)
#     505             else r
#     506             for r in recs
#     507         ]
#     509         # For repeating the metadata later
#
# File ~/miniconda3/envs/nlp/lib/python3.8/site-packages/pandas/io/json/_normalize.py:431, in json_normalize.<locals>._pull_records(js, spec)
#     429         result = []
#     430     else:
# --> 431         raise TypeError(
#     432             f"{js} has non list value {result} for path {spec}. "
#     433             "Must be list or null."
#     434         )
#     435 return result
#
# TypeError: {'id': '1406813874750300166', 'key': [2021, 6, 21, '1405853521107324933', '1055330142313046016', '1406813874750300166'], 'value': {'text': 'Such a cute pupper 😍'}, 'doc': {'_id': '1406813874750300166', '_rev': '1-1a7924e962def1c92ecd08ee1537ea1b', 'data': {'author_id': '1055330142313046016', 'conversation_id': '1405853521107324933', 'created_at': '2021-06-21T03:18:59.000Z', 'entities': {'mentions': [{'start': 0, 'end': 13, 'username': 'pup_chazable'}]}, 'geo': {}, 'lang': 'en', 'public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'text': '@pup_chazable Such a cute pupper 😍', 'sentiment': 0.7142857142857143}, 'matching_rules': [{'id': 1406789634793697300, 'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]}} has non list value {'_id': '1406813874750300166', '_rev': '1-1a7924e962def1c92ecd08ee1537ea1b', 'data': {'author_id': '1055330142313046016', 'conversation_id': '1405853521107324933', 'created_at': '2021-06-21T03:18:59.000Z', 'entities': {'mentions': [{'start': 0, 'end': 13, 'username': 'pup_chazable'}]}, 'geo': {}, 'lang': 'en', 'public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'text': '@pup_chazable Such a cute pupper 😍', 'sentiment': 0.7142857142857143}, 'matching_rules': [{'id': 1406789634793697300, 'tag': 'Australia-based users or Australia-located tweets, but no re-tweets'}]} for path doc. Must be list or null.

# %%
tweets_df
# Out:
#                       id                                                key  \
# 0    1406813874750300166  [2021, 6, 21, 1405853521107324933, 10553301423...
# 1    1406814402272137216  [2021, 6, 21, 1405853521107324933, 14043711962...
# 2    1406920780328312832  [2021, 6, 21, 1405853729555890177, 83195869278...
# 3    1406929052724654084  [2021, 6, 21, 1405853729555890177, 83195869278...
# 4    1406932228165099530  [2021, 6, 21, 1405853924251226112, 91460102205...
# ..                   ...                                                ...
# 995  1406973646577438723  [2021, 6, 21, 1406057579659153409, 11029104390...
# 996  1406987309690482689  [2021, 6, 21, 1406058146934706188, 60866631, 1...
# 997  1406955275370729480  [2021, 6, 21, 1406058213787701249, 122395798, ...
# 998  1407119087780565000  [2021, 6, 21, 1406059272568553472, 1404434184,...
# 999                  NaN                                                NaN
#
#                                             value.text              doc._id  \
# 0                                 Such a cute pupper 😍  1406813874750300166
# 1    Nawww thanks! 🥰 *Nuzzles* right back at ya pup! 😝  1406814402272137216
# 2    Just wondered if the peregrines been named yet...  1406920780328312832
# 3      Thanks. Sorry missed that. Great result though.  1406929052724654084
# 4    Can you point to some of information about thi...  1406932228165099530
# ..                                                 ...                  ...
# 995  I went there for a weeding a few months ago. T...  1406973646577438723
# 996  Australians don’t want to send her to a , n th...  1406987309690482689
# 997                                           So cute!  1406955275370729480
# 998  Because if they are wrong the s will be all ov...  1407119087780565000
# 999                                                NaN                  NaN
#
#                                doc._rev   doc.data.author_id  \
# 0    1-1a7924e962def1c92ecd08ee1537ea1b  1055330142313046016
# 1    1-d6ce7e1e33721a9f3aed148b2cc1a64c  1404371196267819012
# 2    1-b5f329c5063489fa0863165e1660f367   831958692786417669
# 3    1-87635ddc02305a887c0d64952ff47929   831958692786417669
# 4    1-eb8055d1705034e0b1ee1d93c4cac920   914601022051336192
# ..                                  ...                  ...
# 995  1-fcc55d377569d9adad6e9ffde3e153b1  1102910439015370752
# 996  1-5d3d009eae0f57cc9a3efeef64056c01             60866631
# 997  1-5b14e6ffa418a56e5b8f5cdb18ccdaf7            122395798
# 998  1-4130137cc4fbda9e80277775303c2e0a           1404434184
# 999                                 NaN                  NaN
#
#     doc.data.conversation_id       doc.data.created_at  \
# 0        1405853521107324933  2021-06-21T03:18:59.000Z
# 1        1405853521107324933  2021-06-21T03:21:05.000Z
# 2        1405853729555890177  2021-06-21T10:23:48.000Z
# 3        1405853729555890177  2021-06-21T10:56:40.000Z
# 4        1405853924251226112  2021-06-21T11:09:17.000Z
# ..                       ...                       ...
# 995      1406057579659153409  2021-06-21T13:53:52.000Z
# 996      1406058146934706188  2021-06-21T14:48:09.000Z
# 997      1406058213787701249  2021-06-21T12:40:52.000Z
# 998      1406059272568553472  2021-06-21T23:31:48.000Z
# 999                      NaN                       NaN
#
#                             doc.data.entities.mentions doc.data.lang  ...  \
# 0    [{'start': 0, 'end': 13, 'username': 'pup_chaz...            en  ...
# 1    [{'start': 0, 'end': 10, 'username': 'PupLucky...            en  ...
# 2         [{'start': 0, 'end': 5, 'username': 'WKWT'}]            en  ...
# 3         [{'start': 0, 'end': 5, 'username': 'WKWT'}]            en  ...
# 4    [{'start': 0, 'end': 16, 'username': 'Akiyoshi...            en  ...
# ..                                                 ...           ...  ...
# 995  [{'start': 0, 'end': 12, 'username': 'CaroDiRu...            en  ...
# 996       [{'start': 0, 'end': 5, 'username': 'cnni'}]            en  ...
# 997  [{'start': 0, 'end': 13, 'username': 'QuietScr...            en  ...
# 998  [{'start': 0, 'end': 16, 'username': 'Grassroo...            en  ...
# 999                                                NaN           NaN  ...
#
#                          doc.data.entities.annotations  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995                                                NaN
# 996  [{'start': 44, 'end': 52, 'probability': 0.464...
# 997                                                NaN
# 998  [{'start': 74, 'end': 84, 'probability': 0.758...
# 999                                                NaN
#
#      doc.data.sentiment.score  doc.data.sentiment.comparative  \
# 0                         NaN                             NaN
# 1                         NaN                             NaN
# 2                         NaN                             NaN
# 3                         NaN                             NaN
# 4                         NaN                             NaN
# ..                        ...                             ...
# 995                       NaN                             NaN
# 996                       NaN                             NaN
# 997                       NaN                             NaN
# 998                       NaN                             NaN
# 999                       NaN                             NaN
#
#      doc.data.sentiment.calculation doc.data.sentiment.tokens  \
# 0                               NaN                       NaN
# 1                               NaN                       NaN
# 2                               NaN                       NaN
# 3                               NaN                       NaN
# 4                               NaN                       NaN
# ..                              ...                       ...
# 995                             NaN                       NaN
# 996                             NaN                       NaN
# 997                             NaN                       NaN
# 998                             NaN                       NaN
# 999                             NaN                       NaN
#
#      doc.data.sentiment.words doc.data.sentiment.positive  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
# ..                        ...                         ...
# 995                       NaN                         NaN
# 996                       NaN                         NaN
# 997                       NaN                         NaN
# 998                       NaN                         NaN
# 999                       NaN                         NaN
#
#     doc.data.sentiment.negative doc.data.entities.cashtags  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
# ..                          ...                        ...
# 995                         NaN                        NaN
# 996                         NaN                        NaN
# 997                         NaN                        NaN
# 998                         NaN                        NaN
# 999                         NaN                        NaN
#
#     doc.data.entities.hashtags
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ..                         ...
# 995                        NaN
# 996                        NaN
# 997                        NaN
# 998                        NaN
# 999                        NaN
#
# [1000 rows x 31 columns]

# %%
tweets_df['created_at'] = pd.to_datetime(tweets_df['created_at'])

tweets_df['hour'] = tweets_df['created_at'].dt.hour
tweets_df['day'] = tweets_df['created_at'].dt.date

happiest_hour = tweets_df.groupby('hour')['sentiment_score'].sum().idxmax()
happiest_day = tweets_df.groupby('day')['sentiment_score'].sum().idxmax()
most_active_hour = tweets_df['hour'].value_counts().idxmax()
most_active_day = tweets_df['day'].value_counts().idxmax()

print(f"Happiest hour: {happiest_hour}")
print(f"Happiest day: {happiest_day}")
print(f"Most active hour: {most_active_hour}")
print(f"Most active day: {most_active_day}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/nlp/lib/python3.8/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/miniconda3/envs/nlp/lib/python3.8/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/miniconda3/envs/nlp/lib/python3.8/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'created_at'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 2
#       1 # Convert the created_at column to datetime
# ----> 2 tweets_df['created_at'] = pd.to_datetime(tweets_df['created_at'])
#       4 # Extract the hour and day from the created_at column
#       5 tweets_df['hour'] = tweets_df['created_at'].dt.hour
#
# File ~/miniconda3/envs/nlp/lib/python3.8/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/miniconda3/envs/nlp/lib/python3.8/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'created_at'
